# %% [markdown]
# Tutorial 02
#
# 1. Re-do Tutorial 1 assignment with numpy. (This should be fairly easy, but use only numpy functions to reproduce your results)
#
# 2. Use the data from Beehive_data.csv to find the distance to the Beehive Cluster. Read on ahead to find out more about the concepts in astronomy you will need to solve this.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Solution to Tutorial 02

# %% [markdown]
# Part 1

# %% [markdown]
# Re-do Tutorial 1 assignment with numpy. (This should be fairly easy, but use only numpy functions to reproduce your results)
#
#
# 1.  Find the number of moons of each planet

# %%
import numpy as np

# %%
moons_and_planets = np.loadtxt('Moons_and_planets.csv', delimiter = ',', dtype = str)
print(moons_and_planets)
# Out:
# [['Moon' 'Earth' '1737.1']
#  ['Phobos' 'Mars' '11.1']
#  ['Deimos' 'Mars' '6.2']
#  ['Io' 'Jupiter' '1818.1']
#  ['Europa' 'Jupiter' '1560.7']
#  ['Ganymede' 'Jupiter' '2634.1']
#  ['Callisto' 'Jupiter' '2408.4']
#  ['Amalthea' 'Jupiter' '83.5']
#  ['Himalia' 'Jupiter' '67.0']
#  ['Elara' 'Jupiter' '43.0']
#  ['Pasiphae' 'Jupiter' '30.0']
#  ['Sinope' 'Jupiter' '19.0']
#  ['Lysithea' 'Jupiter' '18.0']
#  ['Carme' 'Jupiter' '23.0']
#  ['Ananke' 'Jupiter' '14.0']
#  ['Leda' 'Jupiter' '10.0']
#  ['Thebe' 'Jupiter' '49.3']
#  ['Adrastea' 'Jupiter' '8.2']
#  ['Metis' 'Jupiter' '21.5']
#  ['Callirrhoe' 'Jupiter' '4.3']
#  ['Themisto' 'Jupiter' '4.0']
#  ['Megaclite' 'Jupiter' '2.7']
#  ['Taygete' 'Jupiter' '2.5']
#  ['Chaldene' 'Jupiter' '1.9']
#  ['Harpalyke' 'Jupiter' '2.2']
#  ['Kalyke' 'Jupiter' '2.6']
#  ['Iocaste' 'Jupiter' '2.6']
#  ['Erinome' 'Jupiter' '1.6']
#  ['Isonoe' 'Jupiter' '1.9']
#  ['Praxidike' 'Jupiter' '3.4']
#  ['Autonoe' 'Jupiter' '2.0']
# ...

# %%
planets = moons_and_planets[:, 1]
print(planets)
# Out:
# ['Earth' 'Mars' 'Mars' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter'
#  'Jupiter' 'Jupiter' 'Jupiter' 'Jupiter' 'Saturn' 'Saturn' 'Saturn'
#  'Saturn' 'Saturn' 'Saturn' 'Saturn' 'Saturn' 'Saturn' 'Saturn' 'Saturn'
# ...

# %%
count1 = 0
for planet in planets:
    if 'Mercury' in planet:
        count1 = count1 + 1

count2 = 0
for planet in planets:
    if 'Venus' in planet:
        count2 = count2 + 1

count3 = 0
for planet in planets:
    if 'Earth' in planet:
        count3 = count3 + 1

count4 = 0
for planet in planets:
    if 'Mars' in planet:
        count4 = count4 + 1

count5 = 0
for planet in planets:
    if 'Jupiter' in planet:
        count5 = count5 + 1

count6 = 0
for planet in planets:
    if 'Saturn' in planet:
        count6 = count6 + 1

count7 = 0
for planet in planets:
    if 'Uranus' in planet:
        count7 = count7 + 1

count8 = 0
for planet in planets:
    if 'Neptune' in planet:
        count8 = count8 + 1

count9 = 0
for planet in planets:
    if 'Pluto' in planet:
        count9 = count9 + 1

print('The number of moons of each planet are as follows:')
print('Mercury:', count1)
print('Venus:', count2)
print('Earth:', count3)
print('Mars:', count4)
print('Jupiter:', count5)
print('Saturn:', count6)
print('Uranus:', count7)
print('Neptune:', count8)
print('Pluto:', count9)

total_count = count1 + count2 + count3 + count4 + count5 + count6 + count7 + count8 + count9

print(f"The total number of moons are {total_count}.")
# Out:
# The number of moons of each planet are as follows:
# Mercury: 0
# Venus: 0
# Earth: 1
# Mars: 2
# Jupiter: 79
# Saturn: 82
# Uranus: 27
# Neptune: 14
# Pluto: 5
# The total number of moons are 210.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 2.  Order the moons (along with their planets) according to their sizes.

# %%
#diameters = moons_and_planets[:, 2].astype(float)
#moons_and_planets[0:,2] = diameters

# print(diameters)
#print(moons_and_planets)
#moons_and_planets[:,2].dtype

# %%
moons_and_planets_sorted = moons_and_planets[moons_and_planets[:, 2].astype(float).argsort()]

print(moons_and_planets_sorted)
# Out:
# [['S/2009 S 1' 'Saturn' '0.15']
#  ['Aegaeon' 'Saturn' '0.33']
#  ['S/2011 J 1' 'Jupiter' '0.5']
#  ['S/2010 J 2' 'Jupiter' '0.5']
#  ['S/2003 J 12' 'Jupiter' '0.5']
#  ['S/2011 J 2' 'Jupiter' '0.5']
#  ['S/2003 J 9' 'Jupiter' '0.5']
#  ['Valetudo' 'Jupiter' '0.5']
#  ['S/2017 J 8' 'Jupiter' '0.5']
#  ['Kore' 'Jupiter' '1.0']
#  ['Philophrosyne' 'Jupiter' '1.0']
#  ['S/2003 J 18' 'Jupiter' '1.0']
#  ['Euporie' 'Jupiter' '1.0']
#  ['Orthosie' 'Jupiter' '1.0']
#  ['Sponde' 'Jupiter' '1.0']
#  ['S/2017 J 3' 'Jupiter' '1.0']
#  ['Pasithee' 'Jupiter' '1.0']
#  ['Mneme' 'Jupiter' '1.0']
#  ['Thelxinoe' 'Jupiter' '1.0']
#  ['Kallichore' 'Jupiter' '1.0']
#  ['S/2010 J 1' 'Jupiter' '1.0']
#  ['Cyllene' 'Jupiter' '1.0']
#  ['Kale' 'Jupiter' '1.0']
#  ['Eupheme' 'Jupiter' '1.0']
#  ['Herse' 'Jupiter' '1.0']
#  ['S/2017 J 7' 'Jupiter' '1.0']
#  ['S/2003 J 4' 'Jupiter' '1.0']
#  ['S/2003 J 2' 'Jupiter' '1.0']
#  ['Ersa' 'Jupiter' '1.0']
#  ['S/2017 J 9' 'Jupiter' '1.0']
# ...

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Part 2
#
# Use the data from Beehive_data.csv to find the distance to the Beehive Cluster. Read on ahead to find out more about the concepts in astronomy you will need to solve this.
#
# 1.  Exclude all the stars with low probability of belonging to the cluster, and then calculate distance for each star, and find the mean.

# %%
Beehive_data = np.loadtxt("Beehive_data.csv", delimiter = ",", dtype = float)

#prob = Beehive_data[:,2]

#prob_reshaped = prob.reshape(-1, 1)
#print(prob_reshaped)


#rounded_columns = np.round(Beehive_data[:,:2], 2)
#print(rounded_columns)

#Beehive_data[:,0] = np.round(Beehive_data[:,0], 2)
#Beehive_data[:,1] = np.round(Beehive_data[:,1], 2)
#Beehive_data[:,2] = np.round(Beehive_data[:,2], 1)


np.set_printoptions(precision=2, suppress=True, floatmode='maxprec')

#print(np.round(Beehive_data, 1))
print(Beehive_data)
print(len(Beehive_data))
# Out:
# [[  6.3    1.77 100.  ]
#  [  6.39   1.85 100.  ]
#  [  6.44   1.85 100.  ]
#  [  6.59   1.76 100.  ]
#  [  6.61   1.72  35.  ]
#  [  6.61   1.72  47.  ]
#  [  6.61   1.72  17.  ]
#  [  6.67   1.62 100.  ]
#  [  6.78   1.57 100.  ]
#  [  6.78   1.58 100.  ]
#  [  6.85   1.55 100.  ]
#  [  6.9    1.64 100.  ]
#  [  7.32   1.36 100.  ]
#  [  7.45   1.31 100.  ]
#  [  7.54   1.27 100.  ]
#  [  7.54   1.28  43.  ]
#  [  7.54   1.28  27.  ]
#  [  7.54   1.28  30.  ]
#  [  7.67   1.22  43.  ]
#  [  7.67   1.22  24.  ]
#  [  7.67   1.22  33.  ]
#  [  7.7    1.21  43.  ]
#  [  7.7    1.21  24.  ]
#  [  7.7    1.21  33.  ]
#  [  7.73   1.2  100.  ]
#  [  7.96   1.11 100.  ]
#  [  8.02   1.08 100.  ]
#  [  8.18   1.01 100.  ]
#  [  8.31   0.96 100.  ]
#  [  8.33   0.96 100.  ]
#  [  8.5    0.89 100.  ]
#  [  8.71   0.8  100.  ]
#  [  8.81   0.76 100.  ]
#  [  8.89   0.73 100.  ]
#  [  9.     0.69 100.  ]
#  [  9.04   0.67 100.  ]
#  [  9.23   0.6  100.  ]
#  [  9.31   0.58  62.  ]
# ...

# %%
low_prob = np.where(Beehive_data[:,2] <=50)
Beehive_data_updated = np.delete(Beehive_data, low_prob, axis = 0) # axis = 0 indicates that deletion occurs along the row. axis = 1 is for column deletion.
print(Beehive_data_updated)
print(len(Beehive_data_updated))
# Out:
# [[  6.3    1.77 100.  ]
#  [  6.39   1.85 100.  ]
#  [  6.44   1.85 100.  ]
#  [  6.59   1.76 100.  ]
#  [  6.67   1.62 100.  ]
#  [  6.78   1.57 100.  ]
#  [  6.78   1.58 100.  ]
#  [  6.85   1.55 100.  ]
#  [  6.9    1.64 100.  ]
#  [  7.32   1.36 100.  ]
#  [  7.45   1.31 100.  ]
#  [  7.54   1.27 100.  ]
#  [  7.73   1.2  100.  ]
#  [  7.96   1.11 100.  ]
#  [  8.02   1.08 100.  ]
#  [  8.18   1.01 100.  ]
#  [  8.31   0.96 100.  ]
#  [  8.33   0.96 100.  ]
#  [  8.5    0.89 100.  ]
#  [  8.71   0.8  100.  ]
#  [  8.81   0.76 100.  ]
#  [  8.89   0.73 100.  ]
#  [  9.     0.69 100.  ]
#  [  9.04   0.67 100.  ]
#  [  9.23   0.6  100.  ]
#  [  9.31   0.58  62.  ]
#  [  9.37   0.55 100.  ]
#  [  9.39   0.54 100.  ]
#  [  9.42   0.53 100.  ]
#  [  9.55   0.48 100.  ]
#  [  9.59   0.46 100.  ]
#  [  9.67   0.43 100.  ]
#  [  9.68   0.42 100.  ]
#  [  9.77   0.39 100.  ]
#  [  9.79   0.39 100.  ]
#  [  9.83   0.37 100.  ]
#  [  9.85   0.36 100.  ]
#  [  9.88   0.35 100.  ]
# ...

# %%
def distance_to_Beehive():
    power_raise_to_10 = ((Beehive_data_updated[:,0] + 2.5*(Beehive_data_updated[:,1]) + 0.17)/5)
    d = 10**power_raise_to_10
    return d
    
result = distance_to_Beehive()
print(np.round(result, 2))
print(len(result))
# Out:
# [151.01 172.58 176.6  170.61 150.66 149.62 151.36 151.01 171.4  150.66
#  151.01 150.31 151.36 151.71 150.66 149.62 149.97 151.36 151.01 149.97
#  149.97 150.31 151.01 150.31 151.36 153.46 152.41 152.05 152.41 152.76
#  152.05 152.41 151.36 152.41 153.82 153.11 152.76 153.11 153.82 155.24
#  153.11 153.46 153.46 153.11 155.6  154.53 154.53 157.04 155.24 155.96
#  155.24 155.6  158.12 155.96 157.76 156.68 162.55 159.59 156.68 156.31
#  159.22 170.61 162.18 162.55 179.06 166.34 166.72 179.06 169.04 169.43
#  173.78 173.78 177.83 180.72 184.08 178.65 186.21 187.93 228.03]
# 79

# %%
print(result.mean())
# Out:
# 159.8015962235226

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Part 2
#
# Find the distance for all stars (including the low probability ones) and find the weighted average of the distances, where the weights are the probability.

# %%
def distance_to_Beehive(Beehive_data):
    power_raise_to_10 = ((Beehive_data[:,0] + 2.5*(Beehive_data[:,1]) + 0.17)/5)
    d = 10**power_raise_to_10
    return d
    
result_1 = distance_to_Beehive(Beehive_data)
print(np.round(result, 3))
#print(result)
print(len(result))
# Out:
# [151.01 172.58 176.6  170.61 164.44 164.44 164.44 150.66 149.62 151.36
#  151.01 171.4  150.66 151.01 150.31 152.06 152.06 152.06 150.66 150.66
#  150.66 151.01 151.01 151.01 151.36 151.71 150.66 149.62 149.97 151.36
#  151.01 149.97 149.97 150.31 151.01 150.31 151.36 153.46 153.46 153.46
#  152.41 152.06 152.41 152.76 152.06 152.41 151.36 152.41 153.81 153.11
#  152.76 153.11 153.81 155.24 155.24 155.24 153.11 153.46 153.46 153.11
#  155.6  154.53 154.53 157.04 157.04 157.04 155.24 155.96 155.24 155.6
#  158.12 155.96 157.76 156.68 162.56 159.59 156.68 156.31 159.22 154.17
#  159.96 170.61 162.18 162.56 162.18 179.06 164.06 166.34 166.72 179.06
#  169.04 169.43 170.22 173.78 173.78 177.83 180.72 184.08 178.65 177.83
#  186.21 187.93 165.58 228.03]
# 104

# %%
weighted_terms = result * Beehive_data[:,2]
print(weighted_terms)
# Out:
# [15100.8  17258.38 17660.38 17060.82  5755.3   7728.55  2795.43 15066.07
#  14962.36 15135.61 15100.8  17139.57 15066.07 15100.8  15031.42  6538.35
#   4105.48  4561.64  6478.41  3615.86  4971.8   6493.34  3624.19  4983.26
#  15135.61 15170.5  15066.07 14962.36 14996.85 15135.61 15100.8  14996.85
#  14996.85 15031.42 15100.8  15031.42 15135.61  9514.63  1381.16  4603.85
#  15240.53 15205.48 15240.53 15275.66 15205.48 15240.53 15135.61 15240.53
#  15381.55 15310.87 15275.66 15310.87 15381.55 10245.75  1241.91  4036.21
#  15310.87 15346.17 15346.17 15310.87 15559.66 15452.54 15452.54 12091.79
#    942.22  2826.65 15523.87 15595.53 15523.87 15559.66 15812.48 15595.53
#  15776.11 15667.51 16255.49 15958.79 15667.51 15631.48 15922.09     0.
#      0.   17060.82 16218.1  16255.49     0.   17906.06     0.   16634.13
#  16672.47 17906.06 16904.41 16943.38     0.   17378.01 17378.01 17782.79
#  18071.74 18407.72 17864.88     0.   18620.87 18793.17     0.   22803.42]

# %%
sum_of_weighted_terms = 0
for term in weighted_terms:
    sum_of_weighted_terms += term
print(sum_of_weighted_terms)
# Out:
# 1324394.7357052034

# %%
sum_of_weights = 0
for term in Beehive_data[:,2]:
    sum_of_weights += term
print(sum_of_weights)
# Out:
# 8301.0

# %%
weighted_average = sum_of_weighted_terms / sum_of_weights
print(f"The weighted average of the distances is {weighted_average}.")
# Out:
# The weighted average of the distances is 159.5464083490186.
